# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from scipy.stats import zscore
import importlib
import eda
importlib.reload(eda)
# Out:
# EDA completed successfully.
# <module 'eda' from 'd:\\House_data\\src\\eda.py'>

# %%
house_data = pd.read_csv(r'D:\House_data\raw_data\house_data.csv')

# %%
house_data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='str')

# %%
# print eda of house data 
X_house = house_data.drop(columns=['id', 'zipcode', 'lat', 'long',"date","price"])
y_house = house_data['price']

# %%
plt.Figure(figsize=(12,8))
plt.figure(figsize=(12,8))
bedroom_counts = X_house['bedrooms'].value_counts().sort_index()
plt.bar(bedroom_counts.index, bedroom_counts.values)
plt.title('Number of Houses by Bedroom Count')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 2
#       1 plt.Figure(figsize=(12,8))
# ----> 2 plt.bar(X_house['bedrooms'],height=X_house['bedrooms'].counts())
#
# File d:\Python\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'counts'

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='bedrooms', data=house_data, palette="Set2")
plt.title('Number of Houses by Bedroom Count')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
# Out:
# C:\Users\hanya\AppData\Local\Temp\ipykernel_11856\721819208.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='bedrooms', data=house_data, palette="Set2")
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(12,8))
sns.regplot(x=X_house['sqft_living']**2, y=y_house)
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
eda.eda_house_data(house_data, 'price')

# %%
eda.eda_house_data(house_data, 'price')
