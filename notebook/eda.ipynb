# %% [markdown]
# # Import libraries

# %%
# pip install plotly

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy.stats import zscore
import importlib
import sys
# Import the user-defined module
sys.path.append(r'd:\House_data')
import src.eda as eda
importlib.reload(eda)
# Out:
# <module 'src.eda' from 'd:\\House_data\\src\\eda.py'>

# %% [markdown]
# # Exploratory Data Analysis house data

# %%
house_data = pd.read_csv(r'D:\House_data\raw_data\house_data.csv')
house_data = house_data.drop(columns=['id', 'zipcode',"date"])
eda.eda_house_data(house_data, target='price')
print("EDA completed successfully.")
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ******************************************Data Exploration******************************************
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Data set: house data for this project
#  rows: 21613
# columns: 18
# ----------------------------------------------------------------------------------------------------
# House data demoenstration
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# ...

# %%
plt.figure(figsize=(20, 10))
fig = px.scatter_map(
    house_data,
    lat="lat",
    lon="long",
    color="price",
    size="price",
    zoom=12,
    height=800
)

fig.update_layout(mapbox_style="open-street-map")
fig.show()
